# %%
# %matplotlib widget

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
from datetime import datetime, timedelta

# %%
def calculate_star_temperature(m_B, m_V):
    # Calculate the color indices
    B_V = m_B - m_V
    
    # Calculate the effective temperature using Ballesteros' formula
    T_eff = (4600 / (0.92 * B_V + 1.7)) + (4600 / (0.92 * B_V + 0.62))
    return round(T_eff,3)

def process_temperatures_from_file(file_path):
    temperatures = []
    current_date = start_date
    with open(file_path, newline='') as csvfile:
        reader = csv.DictReader(csvfile)
        for i, row in enumerate(reader):
            m_B = float(row['m_B'])
            m_V = float(row['m_V'])
            T_eff = calculate_star_temperature(m_B, m_V)
            temperatures.append(f"{i + 1} - {current_date.strftime('%Y-%m-%d')}, Temperature: {T_eff} K")
            current_date += timedelta(days=1)
    return temperatures

file_path = '/Users/valegarcia/Downloads/m_b m_v values.csv'
start_date = datetime(2024, 6, 29)
temperatures = process_temperatures_from_file(file_path)
for day_data in temperatures:
    print(day_data)

# %%
import csv

def calculate_star_temperature(m_B, m_V):
    # Calculate the color indices
    B_V = (m_B - m_V) - 0.0402
    
    # Calculate the effective temperature using Ballesteros' formula
    T_eff = (4600 / (0.92 * B_V + 1.7)) + (4600 / (0.92 * B_V + 0.62))
    return round(T_eff, 3)

def process_temperatures_from_file(file_path):
    temperatures = []
    with open(file_path, newline='') as csvfile:
        reader = csv.DictReader(csvfile)
        
        for i, row in enumerate(reader):
            JD = float(row['\ufeffJD'])  # Access the 'JD' column correctly
            m_B = float(row['m_B'])
            m_V = float(row['m_V'])
            T_eff = calculate_star_temperature(m_B, m_V)
            temperatures.append(f"{i + 1} - JD: {JD} -> Temperature: {T_eff} K")
    return temperatures

file_path = '/Users/valegarcia/Downloads/GY CNC.csv'
temperatures = process_temperatures_from_file(file_path)

for temp in temperatures:
    print(temp)
# Out:
# 1 - JD: 2456649.048 -> Temperature: 5972.246 K
# 2 - JD: 2456649.051 -> Temperature: 48646.687 K
# 3 - JD: 2456650.028 -> Temperature: 11171.92 K
# 4 - JD: 2456650.03 -> Temperature: 4986.251 K
# 5 - JD: 2456651.051 -> Temperature: 16801.907 K
# 6 - JD: 2456652.047 -> Temperature: 4975.599 K
# 7 - JD: 2456652.05 -> Temperature: 4348.748 K
# 8 - JD: 2456662.998 -> Temperature: 7713.607 K
# 9 - JD: 2456663.958 -> Temperature: 13170.407 K
# 10 - JD: 2456663.961 -> Temperature: 6063.943 K
# 11 - JD: 2456663.963 -> Temperature: 6833.726 K
# 12 - JD: 2456664.986 -> Temperature: 7679.601 K
# 13 - JD: 2456667.982 -> Temperature: 5183.718 K
# 14 - JD: 2456668.972 -> Temperature: 4876.755 K
# 15 - JD: 2456668.975 -> Temperature: 6243.775 K
# 16 - JD: 2456669.969 -> Temperature: 7375.273 K
# 17 - JD: 2456669.972 -> Temperature: 12088.446 K
# 18 - JD: 2456670.962 -> Temperature: 6472.601 K
# 19 - JD: 2456672.952 -> Temperature: 7463.135 K
# 20 - JD: 2456672.954 -> Temperature: 6349.245 K
# 21 - JD: 2456685.958 -> Temperature: -30293.538 K
# 22 - JD: 2456685.962 -> Temperature: 10041.2 K
# 23 - JD: 2456686.945 -> Temperature: 5333.073 K
# 24 - JD: 2456686.949 -> Temperature: 4897.218 K
# 25 - JD: 2456699.934 -> Temperature: 8633.874 K
# 26 - JD: 2456699.938 -> Temperature: -10092.546 K
# 27 - JD: 2456701.963 -> Temperature: 10988.858 K
# 28 - JD: 2456701.966 -> Temperature: 4619.441 K
# 29 - JD: 2456702.963 -> Temperature: 6606.129 K
# 30 - JD: 2456702.967 -> Temperature: 5299.434 K
# 31 - JD: 2456705.955 -> Temperature: 10844.757 K
# 32 - JD: 2456705.959 -> Temperature: 882.73 K
# 33 - JD: 2456708.955 -> Temperature: 3635.496 K
# 34 - JD: 2456708.959 -> Temperature: 3069.222 K
# 35 - JD: 2456708.959 -> Temperature: 3698.573 K
# 36 - JD: 2456710.488 -> Temperature: 6924.21 K
# 37 - JD: 2456710.95 -> Temperature: 6908.053 K
# 38 - JD: 2456710.954 -> Temperature: 6167.116 K
# 39 - JD: 2456711.959 -> Temperature: 5808.554 K
# 40 - JD: 2456711.963 -> Temperature: 6902.686 K
# 41 - JD: 2456712.914 -> Temperature: 6908.053 K
# 42 - JD: 2456712.917 -> Temperature: 4272.167 K
# 43 - JD: 2456724.886 -> Temperature: 6217.995 K
# 44 - JD: 2456724.89 -> Temperature: 6358.209 K
# 45 - JD: 2456726.861 -> Temperature: 4864.057 K
# 46 - JD: 2456730.873 -> Temperature: 7917.547 K
# 47 - JD: 2456731.843 -> Temperature: 5991.926 K
# 48 - JD: 2456733.875 -> Temperature: 5137.782 K
# 49 - JD: 2456733.879 -> Temperature: 7852.998 K
# 50 - JD: 2456734.862 -> Temperature: 7546.798 K
# 51 - JD: 2456734.866 -> Temperature: 7437.799 K
# 52 - JD: 2456745.805 -> Temperature: 13215.544 K
# 53 - JD: 2456754.759 -> Temperature: 7212.04 K
# 54 - JD: 2456754.762 -> Temperature: 7289.638 K
# 55 - JD: 2456754.764 -> Temperature: 6918.815 K
# 56 - JD: 2456756.777 -> Temperature: 7579.526 K
# 57 - JD: 2456756.779 -> Temperature: 7514.378 K
# 58 - JD: 2456756.781 -> Temperature: 7540.29 K
# 59 - JD: 2456761.335 -> Temperature: 7113.239 K
# 60 - JD: 2456771.737 -> Temperature: 5296.398 K
# 61 - JD: 2456772.696 -> Temperature: 6412.567 K
# 62 - JD: 2456772.699 -> Temperature: 6162.916 K
# 63 - JD: 2456774.738 -> Temperature: 31674.325 K
# 64 - JD: 2456775.39 -> Temperature: 7079.068 K
# 65 - JD: 2456775.392 -> Temperature: 6596.394 K
# 66 - JD: 2456776.417 -> Temperature: 7475.874 K

# %%
import csv

def calculate_star_temperature(m_B, m_V):
    # Calculate the color indices
    B_V = (m_B - m_V) - 0.0402
    return round(B_V, 3)

def process_temperatures_from_file(file_path):
    data = []
    with open(file_path, newline='') as csvfile:
        reader = csv.DictReader(csvfile)
        
        for i, row in enumerate(reader):
            JD = float(row['\ufeffJD'])  # Access the 'JD' column correctly
            m_B = float(row['m_B'])
            m_V = float(row['m_V'])
            B_V = calculate_star_temperature(m_B, m_V)
            data.append(f"{i + 1} - m_B - m_V: {B_V}")
    return data

#This is the file path we need to change every time we wanna access to a new data
file_path = '/Users/valegarcia/Downloads/GY CNC.csv'

data = process_temperatures_from_file(file_path)

for temp in data:
    print(temp)
# Out:
# 1 - m_B - m_V: 0.599
# 2 - m_B - m_V: -0.562
# 3 - m_B - m_V: -0.075
# 4 - m_B - m_V: 0.904
# 5 - m_B - m_V: -0.305
# 6 - m_B - m_V: 0.908
# 7 - m_B - m_V: 1.18
# 8 - m_B - m_V: 0.262
# 9 - m_B - m_V: -0.182
# 10 - m_B - m_V: 0.576
# 11 - m_B - m_V: 0.409
# 12 - m_B - m_V: 0.267
# 13 - m_B - m_V: 0.833
# 14 - m_B - m_V: 0.946
# 15 - m_B - m_V: 0.533
# 16 - m_B - m_V: 0.314
# 17 - m_B - m_V: -0.129
# 18 - m_B - m_V: 0.482
# 19 - m_B - m_V: 0.3
# 20 - m_B - m_V: 0.509
# 21 - m_B - m_V: -0.816
# 22 - m_B - m_V: 0.007
# 23 - m_B - m_V: 0.783
# 24 - m_B - m_V: 0.938
# 25 - m_B - m_V: 0.143
# 26 - m_B - m_V: -0.988
# 27 - m_B - m_V: -0.063
# 28 - m_B - m_V: 1.053
# 29 - m_B - m_V: 0.454
# 30 - m_B - m_V: 0.794
# 31 - m_B - m_V: -1.546
# 32 - m_B - m_V: -1.291
# 33 - m_B - m_V: 1.61
# 34 - m_B - m_V: 2.1
# 35 - m_B - m_V: 1.565
# 36 - m_B - m_V: 0.392
# 37 - m_B - m_V: 0.395
# 38 - m_B - m_V: 0.551
# 39 - m_B - m_V: 0.642
# 40 - m_B - m_V: 0.396
# 41 - m_B - m_V: 0.395
# 42 - m_B - m_V: 1.219
# 43 - m_B - m_V: 0.539
# 44 - m_B - m_V: 0.507
# 45 - m_B - m_V: 0.951
# 46 - m_B - m_V: 0.233
# 47 - m_B - m_V: 0.594
# 48 - m_B - m_V: 0.849
# 49 - m_B - m_V: 0.242
# 50 - m_B - m_V: 0.287
# 51 - m_B - m_V: 0.304
# 52 - m_B - m_V: -0.184
# 53 - m_B - m_V: 0.341
# 54 - m_B - m_V: 0.328
# 55 - m_B - m_V: 0.393
# 56 - m_B - m_V: 0.282
# 57 - m_B - m_V: 0.292
# 58 - m_B - m_V: 0.288
# 59 - m_B - m_V: 0.358
# 60 - m_B - m_V: 0.795
# 61 - m_B - m_V: 0.495
# 62 - m_B - m_V: 0.552
# 63 - m_B - m_V: -0.495
# 64 - m_B - m_V: 0.364
# 65 - m_B - m_V: 0.456
# 66 - m_B - m_V: 0.298

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-darkgrid')

def extract_data(temperatures):
    JDs = []
    T_effs = []
    for entry in temperatures:
        parts = entry.split(' -> ')
        JD_part = parts[0].split(': ')[1]
        T_eff_part = parts[1].split(': ')[1].split(' ')[0]
        
        JDs.append(float(JD_part))
        T_effs.append(float(T_eff_part))
    
    return JDs, T_effs

def plot_temperatures(JDs, T_effs):
    plt.figure(figsize=(10, 6))
    plt.plot(JDs, T_effs, marker='o', markersize=1, color= 'darkorange', alpha= 0.5)
    plt.xlabel('Julian Date (JD)')
    plt.ylabel('Effective Temperature (K)')
    plt.title('Star Temperature over Julian Dates')
    plt.grid(True)
    plt.show()

JDs, T_effs = extract_data(temperatures)
plot_temperatures(JDs, T_effs)

# %%
import pandas as pd
def save_to_excel(JDs, T_effs, output_path):
    data = {'Julian Date (JD)': JDs, 'Effective Temperature (K)': T_effs}
    df = pd.DataFrame(data)
    df.to_excel(output_path, index=False)
    print(f"Data successfully saved to {output_path}")

output_path = '/Users/valegarcia/Downloads/star_temperatures.xlsx'
save_to_excel(JDs, T_effs, output_path)
