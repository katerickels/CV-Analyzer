# %% [markdown]
# # Light Curve of one sector

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import lightkurve as lk

# %%
#BH Lyn
TIC = 'TIC 102604645'

sector_data = lk.search_lightcurve(TIC, author = 'SPOC')

sector_data
# Out:
# SearchResult containing 5 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 14 2019   SPOC     120   102604645      0.0
#   1 TESS Sector 54 2022   SPOC     120   102604645      0.0
#   2 TESS Sector 55 2022   SPOC     120   102604645      0.0
#   3 TESS Sector 74 2024   SPOC     120   102604645      0.0
#   4 TESS Sector 75 2024   SPOC     120   102604645      0.0

# %%
lc = sector_data.download()

import matplotlib.pyplot as plt
lc.plot(linewidth = 0, marker = '.', color = 'navy', alpha = 0.4)
# Out:
# /Users/valegarcia/anaconda3/lib/python3.10/site-packages/lightkurve/search.py:414: LightkurveWarning: Warning: 5 files available to download. Only the first file has been downloaded. Please use `download_all()` or specify additional criteria (e.g. quarter, campaign, or sector) to limit your search.
#   warnings.warn(
# <img src="data:image/png;base64,..." width="848.5">
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %% [markdown]
# ## Normalize Data

# %%
lc_normalized = lc.normalize()
lc_normalized.plot(linewidth = 0, marker = '.', color = 'b', alpha = 0.4)
# Out:
# <img src="data:image/png;base64,..." width="848.5">
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %% [markdown]
# ## Bin data of one sector

# %%
bin_time = 15/24/60

lc_binned = lc_normalized.bin(bin_time)

# %%
lc_binned.plot()
# Out:
# <img src="data:image/png;base64,..." width="848.5">
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %% [markdown]
# ## Binned and Unbinned data together

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize = (8,5))

lc_normalized.plot(ax = ax, linewidth = 0, marker = '.', color = 'gold', markersize = 1)
lc_binned.plot(ax = ax, color = 'k') #linewidth = 0, marker = 'o', markersize = 1)
# Out:
# <img src="data:image/png;base64,..." width="800">
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %% [markdown]
# # Light Curve from multiple sectors

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import lightkurve as lk

# %%
#V416 Dra
TIC_2 = 'TIC 842270790'

sector_data_all = lk.search_lightcurve(TIC_2, author = 'SPOC')

sector_data_all
# Out:
# SearchResult containing 1 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 72 2023   SPOC     120   842270790      0.0

# %%
select_sector = sector_data_all[0:4]

select_sector
# Out:
# SearchResult containing 1 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 72 2023   SPOC     120   842270790      0.0

# %%
lc_coll = select_sector.download_all()

# %%
import matplotlib.pyplot as plt
lc_coll.plot(linewidth = 0, marker = '.', color = 'green', alpha = 0.4)
# Out:
# <img src="data:image/png;base64,..." width="848.5">
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %% [markdown]
# ## Normalize & Stitch Data

# %%
lc_coll_stitched = lc_coll.stitch()

# %%
lc_coll_stitched.plot(linewidth = 0, marker = '.', color = 'firebrick', alpha = 0.2)
# Out:
# <img src="data:image/png;base64,..." width="848.5">
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %% [markdown]
# ## Bin data of multiple sectors

# %%
bin_time = 15/24/60

lc_coll_binned = lc_coll_stitched.bin(bin_time)

# %%
lc_coll_binned.plot()
# Out:
# <img src="data:image/png;base64,..." width="848.5">
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %% [markdown]
# ## Binned and Unbinned data together for multiple sectors

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize = (8,5))

lc_coll_stitched.plot(ax = ax, linewidth = 0, marker = '.', color = 'gold', markersize = 1)
lc_coll_binned.plot(ax = ax, color = 'k') #linewidth = 0, marker = 'o', markersize = 1)
# Out:
# <img src="data:image/png;base64,..." width="800">
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
29.78*1200*1000
# Out:
# 35736000.0
