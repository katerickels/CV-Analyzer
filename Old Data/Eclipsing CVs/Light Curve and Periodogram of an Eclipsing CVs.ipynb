# %% [markdown]
# ## Light Curve and Periodogram of an Eclipsing CVs

# %%
# %matplotlib widget

import numpy as np
import matplotlib.pyplot as plt

import lightkurve as lk

# %%
# Specify the Eclipsing CVs: 
TIC = 'TIC 364173220'

data_all = lk.search_lightcurve(TIC)

data_all
# Out:
# SearchResult containing 3 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 55 2022      SPOC     120   364173220      0.0
#   1 TESS Sector 55 2022 TESS-SPOC     600   364173220      0.0
#   2 TESS Sector 55 2022     CDIPS    1800   364173220      0.0

# %%
import matplotlib.pyplot as plt

data = data_all[0:2]

lc = data.download_all().stitch()

#lc.to_csv('TIC236005060.csv')
#lc.to_fits('TIC236005060.fits')

p = lc.plot(linewidth = 0, marker = '.', color = 'k')

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import matplotlib.pyplot as plt

data = data_all[9]

lc = data.download_all().stitch()

p = lc.plot(linewidth = 0, marker = '.', color = 'r')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 data = data_all[9]
#       5 lc = data.download_all().stitch()
#       7 p = lc.plot(linewidth = 0, marker = '.', color = 'r')
#
# File /opt/homebrew/lib/python3.11/site-packages/lightkurve/search.py:211, in SearchResult.__getitem__(self, key)
#     209 def __getitem__(self, key):
#     210     """Implements indexing and slicing, e.g. SearchResult[2:5]."""
# --> 211     selection = self.table[key]
#     212     # Indexing a Table with an integer will return a Row
#     213     if isinstance(selection, Row):
#
# File /opt/homebrew/lib/python3.11/site-packages/astropy/table/table.py:2095, in Table.__getitem__(self, item)
#    2093     return self.columns[item]
#    2094 elif isinstance(item, (int, np.integer)):
# -> 2095     return self.Row(self, item)
#    2096 elif (
#    2097     isinstance(item, np.ndarray) and item.shape == () and item.dtype.kind == "i"
#    2098 ):
#    2099     return self.Row(self, item.item())
#
# File /opt/homebrew/lib/python3.11/site-packages/astropy/table/row.py:41, in Row.__init__(self, table, index)
#      38 n = len(table)
#      40 if index < -n or index >= n:
# ---> 41     raise IndexError(
#      42         f"index {index} out of range for table with length {len(table)}"
#      43     )
#      45 # Finally, ensure the index is positive [#8422] and set Row attributes
#      46 self._index = index % n
#
# IndexError: index 9 out of range for table with length 3

# %%
import matplotlib.pyplot as plt

data = data_all[8]

lc = data.download_all().stitch()

p = lc.plot(linewidth = 0, marker = '.', color = 'r')

plt.show()

# %%
periodogram = lc.to_periodogram()

fig_LS, ax_LS = plt.subplots(1,1,num=4)
periodogram.plot(ax=ax_LS)
ax_LS.set_xlabel(r'${\rm Frequency~[c/d]}$', fontsize=14)
ax_LS.set_ylabel(r'${\rm Amplitude}$', fontsize=14)
ax_LS.set_xlim(1, 350)
# fig_LS.tight_layout()
plt.show()

# %%
#Second number gotten from the strongest peak of the Periodogram. Changed every time you have a new chart.
period=1/7.75475010149055
print(period)

# %%
0.247-.008

# %%
0.12895322053096062*24

# %%
1/4.077

# %%
.129*24
